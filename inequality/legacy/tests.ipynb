# %%
from gcsfs import GCSFileSystem
import xarray as xr

fs = GCSFileSystem()
files = fs.ls('rhg-data/impactlab-rhg/coastal/sliiders/output/')
for f in files[:10]:
    print(f)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 5
#       1 from gcsfs import GCSFileSystem
#       2 import xarray as xr
#       3
#       4 fs = GCSFileSystem()
# ----> 5 files = fs.ls('rhg-data/impactlab-rhg/coastal/sliiders/output/')
#       6 for f in files[:10]:
#       7     print(f)
#       8
#
# File /srv/conda/envs/notebook/lib/python3.14/site-packages/fsspec/asyn.py:118, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     115 @functools.wraps(func)
#     116 def wrapper(*args, **kwargs):
#     117     self = obj or args[0]
# --> 118     return sync(self.loop, func, *args, **kwargs)
#
# File /srv/conda/envs/notebook/lib/python3.14/site-packages/fsspec/asyn.py:103, in sync(loop, func, timeout, *args, **kwargs)
#     101     raise FSTimeoutError from return_result
#     102 elif isinstance(return_result, BaseException):
# ...
